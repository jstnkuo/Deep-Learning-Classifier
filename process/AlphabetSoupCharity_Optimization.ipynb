# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns = ['EIN', 'NAME', 'STATUS'])
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0   Association              0                      N     5000              1
# 1  Co-operative         1-9999                      N   108590              1
# 2   Association              0                      N     5000              0
# 3         Trust    10000-24999                      N     6692              1
# 4         Trust  100000-499999                      N   142590              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`

cutoff_value = 157
application_types_to_replace = application_df['APPLICATION_TYPE'].value_counts()[application_df['APPLICATION_TYPE'].value_counts() < cutoff_value].index

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
application_df['CLASSIFICATION'].value_counts()[application_df['CLASSIFICATION'].value_counts() > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cutoff_value = 778
classifications_to_replace = application_df['CLASSIFICATION'].value_counts()[application_df['CLASSIFICATION'].value_counts() < cutoff_value].index

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0   Association              0                      N     5000              1
# 1  Co-operative         1-9999                      N   108590              1
# 2   Association              0                      N     5000              0
# 3         Trust    10000-24999                      N     6692              1
# 4         Trust  100000-499999                      N   142590              1

# %%
# Convert categorical data to numeric with `pd.get_dummies`
dummies_df = pd.get_dummies(application_df)
dummies_df
# Out:
#         ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  APPLICATION_TYPE_T10  \
# 0          5000              1                       0                     1
# 1        108590              1                       0                     0
# 2          5000              0                       0                     0
# 3          6692              1                       0                     0
# 4        142590              1                       0                     0
# ...         ...            ...                     ...                   ...
# 34294      5000              0                       0                     0
# 34295      5000              0                       0                     0
# 34296      5000              0                       0                     0
# 34297      5000              1                       0                     0
# 34298  36500179              0                       0                     0
#
#        APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                         0                    0                    0
# 1                         0                    1                    0
# 2                         0                    0                    0
# 3                         0                    1                    0
# 4                         0                    1                    0
# ...                     ...                  ...                  ...
# 34294                     0                    0                    1
# 34295                     0                    0                    1
# 34296                     0                    1                    0
# 34297                     0                    0                    0
# 34298                     0                    1                    0
#
#        APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        1                    0                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    0                    0                    0  ...
# 34295                    0                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    1                    0                    0  ...
# 34298                    0                    0                    0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 43 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = dummies_df['IS_SUCCESSFUL'].values
X = dummies_df.drop(columns='IS_SUCCESSFUL',axis = 1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 82)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_dim= len(X_train[0])
hidden_layer_1 = 20
hidden_layer_2 = 10
hidden_layer_3 = 5

nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=hidden_layer_1, activation="relu", input_dim=input_dim))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=hidden_layer_2, activation="relu"))

# Third hidden layer
nn_model.add(tf.keras.layers.Dense(units=hidden_layer_3, activation="relu"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                860
#
#  dense_1 (Dense)             (None, 10)                210
#
#  dense_2 (Dense)             (None, 5)                 55
#
#  dense_3 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 1,131
# Trainable params: 1,131
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=120)
# Out:
# Epoch 1/120
# 804/804 [==============================] - 7s 5ms/step - loss: 0.6169 - accuracy: 0.7061
# Epoch 2/120
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5808 - accuracy: 0.7297
# Epoch 3/120
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5732 - accuracy: 0.7309
# Epoch 4/120
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5689 - accuracy: 0.7307
# Epoch 5/120
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5667 - accuracy: 0.7317
# Epoch 6/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5651 - accuracy: 0.7327
# Epoch 7/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5642 - accuracy: 0.7319
# Epoch 8/120
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5636 - accuracy: 0.7334
# Epoch 9/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5628 - accuracy: 0.7330
# Epoch 10/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5629 - accuracy: 0.7325
# Epoch 11/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5622 - accuracy: 0.7340
# Epoch 12/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5619 - accuracy: 0.7341
# Epoch 13/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5615 - accuracy: 0.7339
# Epoch 14/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5609 - accuracy: 0.7346
# Epoch 15/120
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5606 - accuracy: 0.7355
# Epoch 16/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5601 - accuracy: 0.7359
# Epoch 17/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5582 - accuracy: 0.7356
# Epoch 18/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5562 - accuracy: 0.7362
# Epoch 19/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5562 - accuracy: 0.7353
# Epoch 20/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5554 - accuracy: 0.7351
# Epoch 21/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5551 - accuracy: 0.7360
# Epoch 22/120
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5555 - accuracy: 0.7358
# Epoch 23/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5552 - accuracy: 0.7352
# Epoch 24/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5547 - accuracy: 0.7354
# Epoch 25/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5546 - accuracy: 0.7355
# Epoch 26/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5544 - accuracy: 0.7364
# Epoch 27/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5542 - accuracy: 0.7368
# Epoch 28/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5544 - accuracy: 0.7364
# Epoch 29/120
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5545 - accuracy: 0.7362
# Epoch 30/120
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5542 - accuracy: 0.7353
# Epoch 31/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5537 - accuracy: 0.7381
# Epoch 32/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5539 - accuracy: 0.7367
# Epoch 33/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5537 - accuracy: 0.7371
# Epoch 34/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5536 - accuracy: 0.7356
# Epoch 35/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5537 - accuracy: 0.7366
# Epoch 36/120
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5534 - accuracy: 0.7368
# Epoch 37/120
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5536 - accuracy: 0.7374
# Epoch 38/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5532 - accuracy: 0.7364
# Epoch 39/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5529 - accuracy: 0.7366
# Epoch 40/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5533 - accuracy: 0.7369
# Epoch 41/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5527 - accuracy: 0.7361
# Epoch 42/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5529 - accuracy: 0.7371
# Epoch 43/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5530 - accuracy: 0.7373
# Epoch 44/120
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5527 - accuracy: 0.7365
# Epoch 45/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5525 - accuracy: 0.7378
# Epoch 46/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5523 - accuracy: 0.7376
# Epoch 47/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5523 - accuracy: 0.7371
# Epoch 48/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5522 - accuracy: 0.7374
# Epoch 49/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5524 - accuracy: 0.7374
# Epoch 50/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5524 - accuracy: 0.7374
# Epoch 51/120
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5521 - accuracy: 0.7382
# Epoch 52/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5519 - accuracy: 0.7379
# Epoch 53/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5524 - accuracy: 0.7370
# Epoch 54/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5524 - accuracy: 0.7364
# Epoch 55/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5518 - accuracy: 0.7379
# Epoch 56/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5517 - accuracy: 0.7373
# Epoch 57/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5516 - accuracy: 0.7376
# Epoch 58/120
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5518 - accuracy: 0.7386
# Epoch 59/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5519 - accuracy: 0.7375
# Epoch 60/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5514 - accuracy: 0.7382
# Epoch 61/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5510 - accuracy: 0.7379
# Epoch 62/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5508 - accuracy: 0.7379
# Epoch 63/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5506 - accuracy: 0.7380
# Epoch 64/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5506 - accuracy: 0.7380
# Epoch 65/120
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5511 - accuracy: 0.7381
# Epoch 66/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5506 - accuracy: 0.7383
# Epoch 67/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5504 - accuracy: 0.7370
# Epoch 68/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5505 - accuracy: 0.7378
# Epoch 69/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5500 - accuracy: 0.7388
# Epoch 70/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5501 - accuracy: 0.7390
# Epoch 71/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5504 - accuracy: 0.7375
# Epoch 72/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5504 - accuracy: 0.7382
# Epoch 73/120
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5501 - accuracy: 0.7389
# Epoch 74/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5502 - accuracy: 0.7376
# Epoch 75/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5501 - accuracy: 0.7387
# Epoch 76/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5497 - accuracy: 0.7388
# Epoch 77/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5503 - accuracy: 0.7382
# Epoch 78/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5501 - accuracy: 0.7386
# Epoch 79/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5499 - accuracy: 0.7389
# Epoch 80/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5498 - accuracy: 0.7394
# Epoch 81/120
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5500 - accuracy: 0.7385
# Epoch 82/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5498 - accuracy: 0.7379
# Epoch 83/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5493 - accuracy: 0.7391
# Epoch 84/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5501 - accuracy: 0.7382
# Epoch 85/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5496 - accuracy: 0.7387
# Epoch 86/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5497 - accuracy: 0.7376
# Epoch 87/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5455 - accuracy: 0.7383
# Epoch 88/120
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5442 - accuracy: 0.7379
# Epoch 89/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5435 - accuracy: 0.7376
# Epoch 90/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5431 - accuracy: 0.7389
# Epoch 91/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5425 - accuracy: 0.7392
# Epoch 92/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5425 - accuracy: 0.7395
# Epoch 93/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5426 - accuracy: 0.7385
# Epoch 94/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5422 - accuracy: 0.7378
# Epoch 95/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5420 - accuracy: 0.7386
# Epoch 96/120
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5425 - accuracy: 0.7395
# Epoch 97/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5419 - accuracy: 0.7386
# Epoch 98/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5416 - accuracy: 0.7395
# Epoch 99/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5419 - accuracy: 0.7397
# Epoch 100/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5417 - accuracy: 0.7385
# Epoch 101/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5420 - accuracy: 0.7399
# Epoch 102/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5413 - accuracy: 0.7393
# Epoch 103/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5413 - accuracy: 0.7387
# Epoch 104/120
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5412 - accuracy: 0.7392
# Epoch 105/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5405 - accuracy: 0.7402
# Epoch 106/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5409 - accuracy: 0.7391
# Epoch 107/120
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5410 - accuracy: 0.7406
# Epoch 108/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5406 - accuracy: 0.7398
# Epoch 109/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5407 - accuracy: 0.7398
# Epoch 110/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5410 - accuracy: 0.7392
# Epoch 111/120
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5402 - accuracy: 0.7397
# Epoch 112/120
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5405 - accuracy: 0.7387
# Epoch 113/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5406 - accuracy: 0.7401
# Epoch 114/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5402 - accuracy: 0.7392
# Epoch 115/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5398 - accuracy: 0.7389
# Epoch 116/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5399 - accuracy: 0.7393
# Epoch 117/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5399 - accuracy: 0.7388
# Epoch 118/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5399 - accuracy: 0.7395
# Epoch 119/120
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5398 - accuracy: 0.7387
# Epoch 120/120
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5399 - accuracy: 0.7395

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5585 - accuracy: 0.7275 - 512ms/epoch - 2ms/step
# Loss: 0.558512806892395, Accuracy: 0.7274635434150696

# %%
history_df = pd.DataFrame(fit_model.history)
history_df.index +=1
accuracy_plot = history_df.plot(y='accuracy')
import matplotlib.pyplot as plt
plt.title("Optimized Model's Accuracy")
plt.xlabel("Epochs")
plt.savefig("optimized_accuracy.png")

# %%
# Export our model to HDF5 file
nn_model.save('../Models/AlphabetSoupCharity.h5')
